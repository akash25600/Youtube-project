# %%
from googleapiclient.discovery import build
import pymongo
import psycopg2
import pandas as pd
import streamlit as st

# %%
#API key connection
def Api_connect():
    Api_Id="AIzaSyDw_1WmTCSDzHZeY3qDB0sZT-TzOgWSkt0"
    api_service_name="youtube"
    api_version="v3"
    youtube=build(api_service_name, api_version, developerKey=Api_Id)
    return youtube
youtube=Api_connect()

# %%
#get channels information
def get_channel_info(channel_id):
    request=youtube.channels ().list(
                    part="snippet, Content Details, statistics",
                    id=channel_id
    )
    response = request.execute()
    
    for i in response['items']:
        data=dict (Channel_Name=i["snippet"]["title"],
                Channel_Id=i["id"],
                Subscribers=int(i['statistics']['subscriberCount']),
                Views=int(i["statistics"]["viewCount"]),
                Total_Videos=int(i["statistics"]["videoCount"]),
                Channel_Description=i["snippet"]["description"],
                Playlist_Id=i["contentDetails"]["relatedPlaylists"]["uploads"])
    return data

# %%
channel_details=get_channel_info("UCCEQKydMgEFIXA4XDshj0CA")

# %%
channel_details=get_channel_info("UCS3c38DmZc_eA3wlp3uHqIw")

# %%
channel_details=get_channel_info("UChGd9JY4yMegY6PxqpBjpRA")

# %%
channel_details=get_channel_info("UCduIoIMfD8tT3KoU0-zBRgQ")

# %%
channel_details
# Out:
# {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#  'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#  'Subscribers': 58500,
#  'Views': 3828232,
#  'Total_Videos': 255,
#  'Channel_Description': 'நான், இயற்பியல் துறையில் முனைவர் பட்டம், ஜப்பானில் 1.5 வருட ஆராய்ச்சி, அமெரிக்காவில் 2 வருட ஆராய்ச்சி, ஐரோப்பாவில் சுமார் 6 வருட ஆராய்ச்சி ! தற்போது நம்ம ஊரில்  !\n\nஎளிய தமிழில் அனைவரும் ஆர்வமுடன் அறிவியலை தெரிந்துகொள்ளவேண்டும் என்ற நோக்கத்தில் இந்த முயற்சி! என்னுடன் தொடர்பு கொள்ள விரும்பினால் sciencewithsam2020@gmail.com\n\nConnect with me by email sciencewithsam2020@gmail.com\n\nநான் யாரிடமும் பணமோ உதவியோ இந்த சேனல் மூலம் கேட்பதில்லை. ஒரு வேலை என்னுடைய சேனலுக்கு உதவ விரும்பும் நண்பர்கள், தனிப்பட்ட முறையில் மின்னஞ்சல் அனுப்பலாம் \n\nI never ask for money through my channel. If you really want to support my work by any means, write to me personally at my email ID sciencewithsam2020@gmail.com \n\n',
#  'Playlist_Id': 'UUhGd9JY4yMegY6PxqpBjpRA'}

# %%
from pprint import pprint
def get_videos_ids(channel_id):
    video_ids=[]
    response=youtube.channels().list (id=channel_id,
                                        part='contentDetails').execute()
    pprint(response)
    
    Playlist_Id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    next_page_token=None
    while True:
        response1=youtube.playlistItems ().list(
                                                part='snippet',
                                                playlistId=Playlist_Id,
                                                maxResults=50,
                                                pageToken=next_page_token).execute()
        for i in range (len (response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token=response1.get('nextPageToken')
        if next_page_token is None:
            break
    return video_ids

# %%
Video_Ids=get_videos_ids('UChGd9JY4yMegY6PxqpBjpRA')
# Out:
# {'etag': 'cMklfcLeWMx8pmq3IM6vM0n6lQI',
#  'items': [{'contentDetails': {'relatedPlaylists': {'likes': '',
#                                                     'uploads': 'UUhGd9JY4yMegY6PxqpBjpRA'}},
#             'etag': 'YEMZrU2RgEmJ9FfFKs4_SL3YFJg',
#             'id': 'UChGd9JY4yMegY6PxqpBjpRA',
#             'kind': 'youtube#channel'}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 1}}

# %%
len(Video_Ids)
# Out:
# 255

# %%
Video_Ids
# Out:
# ['FTLBylwmrlk',
#  'fjcoW3dtuGM',
#  'IezbYe4KnAg',
#  'Sso4-56DB_g',
#  'D3jiAxVmYr4',
#  'qK3WhbtnYiE',
#  'u8Taq7BftzI',
#  'axyB8eJfA_g',
#  'jUuXuT8OCCc',
#  'G2Hpsf6VjII',
#  'q7CCuy-z16w',
#  '4OzQep0O188',
#  'NLt8jvfRzdE',
#  'YlBN1q_C36g',
#  'I8-ePNI1dOA',
#  'lRsV8HPNmOs',
#  'BKeyxTrBbnY',
#  'fK-9tNPZwl0',
#  '3YLM4syCmm8',
#  'j58-HbDWRww',
#  'hFwavrH8BLU',
#  'UfutXnYu7R8',
#  'uQuwBs7RJHw',
#  'KpuRyc00_t0',
#  'E5O7Nx6lpu0',
#  'qIyIA68T1FY',
#  'PoS7ifimbpk',
#  'NlvuPsZtQJw',
#  'UaBKxzBhdqk',
#  'mRBCCWoK2Qw',
#  'd4Cz8Vcg3tY',
#  'hoJw8D4DrLc',
#  'uob4vPknXkI',
#  'fnnqJ_COroo',
#  'uj2t-A2zACM',
#  'UmCb-7mNREE',
#  'mMpvW8cZDwo',
#  'N6ZV9jPQok0',
#  'RPfhLGAKK3Q',
#  'ruxVRaCchtI',
#  '85aiJYOdK_w',
#  'qqb3HazZLMs',
#  '6yIDo13llWQ',
#  'G6Zvjkz_hSM',
#  '1Vtr7-kWB4I',
#  'tjRZK_1XAro',
#  'mieGqJ0BXiE',
#  'rggw1Izwbf0',
#  'wk30gfF_C_w',
#  'w8D181wzNAE',
#  'Rsv1Gee1X3k',
#  'Uug8GbypVeE',
#  'w-skmswzslw',
#  '-WCqyL_maXw',
#  'IkUnfZ3DZ5E',
# ...

# %%
def get_video_info(video_ids):
    video_data=[]
    for video_id in video_ids:
        request=youtube.videos ().list(
                part="snippet, contentDetails, statistics",
                 id=video_id
        )
        response=request.execute()
        #pprint(response)
        for item in response["items"]:
            data=dict (Channel_Name=item['snippet']['channelTitle'],
                    Channel_Id=item['snippet']['channelId'],
                    Video_Id=item['id'],
                    Title=item ['snippet']['title'],
                    Tags=item['snippet'].get('tags'),
                    Thumbnail=item['snippet']['thumbnails']['default']['url'],
                    Description=item['snippet'].get('description'),
                    PublishedDate=item['snippet']['publishedAt'],
                    Duration=item['contentDetails']['duration'],
                    Views=int(item['statistics'].get('viewCount')),
                    Likes=item['statistics'].get('likesCount'),
                    Comments=item['statistics'].get('commentCount'),
                    Favorite_count=int(item[ 'statistics']['favoriteCount']),
                    Definition=item['contentDetails']['definition'],
                    Caption_Status=item['contentDetails']['caption']
                    )
        video_data.append(data)
    return video_data

# %%
video_details=get_video_info(Video_Ids)

# %%
for i in video_details:
    print(i)
# Out:
# {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !', 'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA', 'Video_Id': 'FTLBylwmrlk', 'Title': 'Nobel Prize Chemistry 2023 Tamil | வேதியில் தேர்வில் FAIL - வேதியியலில் 2023 நோபல் பரிசு |', 'Tags': ['#sciencewithsam'], 'Thumbnail': 'https://i.ytimg.com/vi/FTLBylwmrlk/default.jpg', 'Description': '', 'PublishedDate': '2023-10-05T12:00:10Z', 'Duration': 'PT10M5S', 'Views': 8670, 'Likes': None, 'Comments': '54', 'Favorite_count': 0, 'Definition': 'hd', 'Caption_Status': 'false'}
# ...

# %%
#comment details
def get_comment_info(video_ids):
    Comment_data=[]
    try:
        for video_id in video_ids:
            request=youtube.commentThreads().list(
                                            part="snippet",
                                            videoId=video_id,
                                            maxResults=50)
            response=request.execute()

            for item in response['items']:
                        data=dict(Comment_Id=item['snippet']['topLevelComment']['id'],
                                Video_Id=item['snippet']['topLevelComment']['snippet']['videoId'],
                                Comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                                Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                                Comment_Published=item['snippet']['topLevelComment']['snippet']['publishedAt']
                                )
                        Comment_data.append(data)
                        
    except:
        pass
    return Comment_data

# %%
comment_details=get_comment_info(Video_Ids)

# %%
len(comment_details)
# Out:
# 8447

# %%
comment_details
# Out:
# [{'Comment_Id': 'UgzPyiZl98Uf6Ln_yMh4AaABAg',
#   'Video_Id': 'FTLBylwmrlk',
#   'Comment_Text': 'Sir explain  vectors  calculus  in  physical form please',
#   'Comment_Author': '@mohammediliyas1129',
#   'Comment_Published': '2023-12-15T12:06:15Z'},
#  {'Comment_Id': 'UgznBo5Z0K8uVN2_ro14AaABAg',
#   'Video_Id': 'FTLBylwmrlk',
#   'Comment_Text': 'Bro , we are waiting your vlog post.. hope you are busy . But we r expecting …',
#   'Comment_Author': '@zenguna',
#   'Comment_Published': '2023-12-12T22:59:41Z'},
#  {'Comment_Id': 'Ugz5p6soVO2yW6PvuMF4AaABAg',
#   'Video_Id': 'FTLBylwmrlk',
#   'Comment_Text': 'Sir pls tell particle physics vs Theoretical physics',
#   'Comment_Author': '@kumaran7450',
#   'Comment_Published': '2023-12-08T16:29:50Z'},
#  {'Comment_Id': 'Ugzo5e01DzUt30rBvVh4AaABAg',
#   'Video_Id': 'FTLBylwmrlk',
#   'Comment_Text': 'Sir are you busy? No videos yet',
#   'Comment_Author': '@MithuOppo',
#   'Comment_Published': '2023-11-24T18:23:09Z'},
# ...

# %%
#get_playlist_details
def get_playlist_details(channel_id):
    next_page_token=None
    All_data=[]
    while True:
        request=youtube.playlists().list(
                    part='snippet,contentDetails',
                    channelId=channel_id,
                    maxResults=50,
                    pageToken=next_page_token
        )
        response=request.execute()
        for item in response['items']:
            data=dict (Playlist_Id=item ['id'],
                Title=item['snippet']['title'],
                Channel_Id=item ['snippet']['channelId'],
                Channel_Name=item ['snippet']['channelTitle'],
                PublishedAt=item ['snippet']['publishedAt']
               )
            All_data.append(data)
        next_page_token=response.get('nextPageToken')
        if next_page_token is None:
            break
    return All_data

# %%
playlist_details=get_playlist_details('UChGd9JY4yMegY6PxqpBjpRA')

# %%
len(playlist_details)
# Out:
# 22

# %%
playlist_details
# Out:
# [{'Playlist_Id': 'PLgctjL4oxHAsIkA1Np-1Z3U5ufFeVPBxG',
#   'Title': 'Quantum Mechanics Lectures in Tamil',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2023-03-29T12:23:10Z'},
#  {'Playlist_Id': 'PLgctjL4oxHAuP0ALXEJDuawYaTGyguu2F',
#   'Title': 'Richard Feynman',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2022-12-24T15:03:27Z'},
#  {'Playlist_Id': 'PLgctjL4oxHAv13mHacoQCGidm6mWlK7Pm',
#   'Title': 'Black Hole',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2022-08-25T07:13:57Z'},
#  {'Playlist_Id': 'PLgctjL4oxHAtKInGo2EjXOBq4sqfTfll7',
#   'Title': 'Black Hole',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2022-08-25T07:13:54Z'},
# ...

# %%
#upload to mongodb
Client=pymongo.MongoClient("mongodb+srv://paramanakash88:12345@cluster0.vgwqar5.mongodb.net/?retryWrites=true&w=majority")
db=Client["youtube_data"]

# %%
def channel_details(channel_id):
    ch_details=get_channel_info(channel_id)
    pl_details=get_playlist_details(channel_id)
    vi_ids=get_videos_ids(channel_id)
    vi_details=get_video_info(vi_ids)
    com_details=get_comment_info(vi_ids)

    collection1=db["channel_details"]
    collection1.insert_one({"channel_information":ch_details,"playlist_information":pl_details,
                        "video_information":vi_details,"comment_information":com_details})
    return "upload completed successfully"

# %%
insert=channel_details("UChGd9JY4yMegY6PxqpBjpRA")
# Out:
# {'etag': 'cMklfcLeWMx8pmq3IM6vM0n6lQI',
#  'items': [{'contentDetails': {'relatedPlaylists': {'likes': '',
#                                                     'uploads': 'UUhGd9JY4yMegY6PxqpBjpRA'}},
#             'etag': 'YEMZrU2RgEmJ9FfFKs4_SL3YFJg',
#             'id': 'UChGd9JY4yMegY6PxqpBjpRA',
#             'kind': 'youtube#channel'}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 1}}

# %%
insert
# Out:
# 'upload completed successfully'

# %%
#Table creation for channels
#import mysql.connector

def channels_table():
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345",
                        #database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()

    drop_query='''drop table if exists channels'''
    cursor.execute(drop_query)
    mydb.commit()


    try:
        create_query='''create table if not exists channels(Channel_Name varchar(100),
                                                            Channel_Id varchar(80) primary key,
                                                            Subscribers bigint,
                                                            Views bigint,
                                                            Total_Videos int,
                                                            Channel_Description text,
                                                            Playlist_Id varchar(80))'''
        cursor.execute(create_query)
        mydb.commit()
                        
    except:
        print("Channels table already created")

    ch_list=[]
    db=Client["youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0, "channel_information":1}):
       # for i in range(len(ch_data["channel_information"])):
            ch_list.append(ch_data["channel_information"])
    df=pd.DataFrame(ch_list)  

    for index,row in df.iterrows():
        insert_query='''insert into channels(Channel_Name,
                                            Channel_Id,
                                            Subscribers,
                                            Views,
                                            Total_Videos,
                                            Channel_Description,
                                            Playlist_Id)

                                            values(%s,%s,%s,%s,%s,%s,%s)'''
        values=(row['Channel_Name'],
                row['Channel_Id'],
                row['Subscribers'],
                row ['Views'],
                row['Total_Videos'],
                row['Channel_Description'],
                row['Playlist_Id'])
        
        try:
            cursor.execute(insert_query,values)
            mydb.commit()
        except:
            print("Channels values are already inserted")

# %%
channels_table()

# %%
ch_list=[]
db=Client["youtube_data"]
coll1=db["channel_details"]
for ch_data in coll1.find({},{"_id":0, "channel_information":1}):
    # for i in range(len(ch_data["channel_information"])):
        ch_list.append(ch_data["channel_information"])
df=pd.DataFrame(ch_list) 
df
# Out:
#                             Channel_Name                Channel_Id  \
# 0  Science With Sam - அறிவியல் அறிவோம் !  UChGd9JY4yMegY6PxqpBjpRA
#
#    Subscribers    Views  Total_Videos  \
# 0        58400  3821416           255
#
#                                  Channel_Description               Playlist_Id
# 0  நான், இயற்பியல் துறையில் முனைவர் பட்டம், ஜப்பா...  UUhGd9JY4yMegY6PxqpBjpRA

# %%
#playlist table
def playlists_table():
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345",
                        #database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()

    drop_query='''drop table if exists playlists'''
    cursor.execute(drop_query)
    mydb.commit()
    
    create_query='''create table if not exists playlists(Playlist_Id varchar(100) primary key,
                                                         Title varchar(100),
                                                         Channel_Id varchar(100),
                                                         Channel_Name varchar(100)
                                                         
                                                         
                                                         )'''
    cursor.execute(create_query)
    mydb.commit()

    pl_list=[]
    db=Client["youtube_data"]
    coll1=db["channel_details"]
    for pl_data in coll1.find({},{"_id":0, "playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append(pl_data["playlist_information"][i])
    df1=pd.DataFrame(pl_list)
 



    for index,row in df1.iterrows():
        insert_query='''insert into playlists(Playlist_Id,
                                            Title,
                                            Channel_Id,
                                            Channel_Name
                                            
                                           )

                                            values(%s,%s,%s,%s)'''
        values=(row['Playlist_Id'],
                row['Title'],
                row['Channel_Id'],
                row['Channel_Name']
                
                )
        
        
        cursor.execute(insert_query,values)
        mydb.commit()

# %%
pl_list=[]
db=Client["youtube_data"]
coll1=db["channel_details"]
for pl_data in coll1.find({},{"_id":0, "playlist_information":1}):
    for i in range(len(pl_data["playlist_information"])):
        pl_list.append(pl_data["playlist_information"][i])
df1=pd.DataFrame(pl_list)
df1
# Out:
#                            Playlist_Id  \
# 0   PLgctjL4oxHAsIkA1Np-1Z3U5ufFeVPBxG
# 1   PLgctjL4oxHAuP0ALXEJDuawYaTGyguu2F
# 2   PLgctjL4oxHAv13mHacoQCGidm6mWlK7Pm
# 3   PLgctjL4oxHAtKInGo2EjXOBq4sqfTfll7
# 4   PLgctjL4oxHAuTH4vM5Y3Fp-1yNC4Rq4j7
# 5   PLgctjL4oxHAs0VfJNQQW1EwL7KZ9LIowl
# 6   PLgctjL4oxHAvnDjqxswXeE0P_CIPb6uYH
# 7   PLgctjL4oxHAu-RXkV4tveHlaOxLjCNJHK
# 8   PLgctjL4oxHAt4WfbhvFDlrr1SdyHRfscT
# 9   PLgctjL4oxHAvRKVXTk2IxLLukcIx37M9i
# 10  PLgctjL4oxHAtDbFuxurdSy8i1KqA7gj-j
# 11  PLgctjL4oxHAtGXWmhboYnCoP8X54pjsUS
# 12  PLgctjL4oxHAvdYFwFKSouv3dSUP1MwZza
# 13  PLgctjL4oxHAsgcE80AV8WCxthkTuUWXN_
# 14  PLgctjL4oxHAvjDhQagRWibAdwp6dg5XG0
# 15  PLgctjL4oxHAtYcFQ8rHuTnHyuCMtTijtt
# 16  PLgctjL4oxHAuRq-InrjEEZVTIlCa6vMJ-
# 17  PLgctjL4oxHAsb2h9SPYwem9az_GLByma2
# 18  PLgctjL4oxHAtmeIUKd4hF16hSd6T2sB1P
# 19  PLgctjL4oxHAtztRaw1tAdq36yi5kR-Ccp
# 20  PLgctjL4oxHAuKwKjtB5mm7IFb_mfHS1w0
# 21  PLgctjL4oxHAspkFL8qJdpeV5GJaH0-KIA
#
# ...

# %%
playlists_table()

# %%
mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345",
                        database="youtube_data",
                        port="5432")
cursor=mydb.cursor()

drop_query='''drop table if exists playlists'''
cursor.execute(drop_query)
mydb.commit()

try:
    create_query='''create table if not exists playlists(Playlist_Id varchar(100) primary key,
                                                        Title varchar(100),
                                                        Channel_Id varchar(100),
                                                        Channel_Name varchar(100),
                                                        PublishedAt timestamp
                                                        
                                                        )'''
    cursor.execute(create_query)
    mydb.commit()
except:
    print("playlist table already created")

# %%
pl_list=[]
db=Client["youtube_data"]
coll1=db["channel_details"]
for pl_data in coll1.find({},{"_id":0, "playlist_information":1}):
    for i in range(len(pl_data["playlist_information"])):
        pl_list.append(pl_data["playlist_information"][i])
df1=pd.DataFrame(pl_list)
df1
# Out:
#                            Playlist_Id                   Title  \
# 0   PLs5oZZ3RfFiU6kOfUjOfMkNv46KK3x5uF                  Shorts
# 1   PLs5oZZ3RfFiVYrz7TgsBK1gvkuLig6irv           Movie Reviews
# 2   PLs5oZZ3RfFiXEwaAFH1-Rq-nWmcFsjbxR           Mystery Cases
# 3   PLs5oZZ3RfFiUan7yndKkzoTuBysHZdT1r                 Stories
# 4   PLs5oZZ3RfFiU-cKKHgk_vtuwKqamMZ7UZ       Life Saving Facts
# ..                                 ...                     ...
# 66  PLt3oFvlHiKAreGE7Pox7JK-7njrXLNnFW    வித்தியாசமான படங்கள்
# 67  PLt3oFvlHiKAqcuB0FQbGNjOHKs1yMeCx0  குறும்படம் Short Films
# 68  PLt3oFvlHiKAoBOIWoSzM-T_80j4WdiKpX  டிராகன் பற்றிய படங்கள்
# 69  PLt3oFvlHiKAq5Z8G3z1FkoiMXnv3J5-Sz   கடவுள் பற்றிய படங்கள்
# 70  PLt3oFvlHiKAr8G7yhyBIq-NPo7ILL0ctR        God of War Tamil
#
#                   Channel_Id         Channel_Name           PublishedAt  \
# 0   UCCEQKydMgEFIXA4XDshj0CA      Minutes Mystery  2023-07-13T11:07:07Z
# ...

# %%
def playlists_table():
        mydb=psycopg2.connect(host="localhost",
                                user="postgres",
                                password="12345",
                                database="youtube_data",
                                port="5432")
        cursor=mydb.cursor()

        

        for index,row in df1.iterrows():
                insert_query='''insert into playlists(Playlist_Id,
                                                Title,
                                                Channel_Id,
                                                Channel_Name,
                                                PublishedAt
                                                )

                                                values(%s,%s,%s,%s,%s)'''
                values=(row['Playlist_Id'],
                        row['Title'],
                        row['Channel_Id'],
                        row['Channel_Name'],
                        row['PublishedAt']
                        )
                
                
                cursor.execute(insert_query,values)
                mydb.commit()

# %%
playlists_table()

# %%
#video tables
def videos_table():
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345",
                        #database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()

    drop_query='''drop table if exists videos'''
    cursor.execute(drop_query)
    mydb.commit()

    create_query='''create table if not exists videos(Channel_Name varchar(100),
                                                        Channel_Id varchar(100),
                                                        Video_Id varchar(30) primary key,
                                                        Title varchar(150),
                                                        Tags text,
                                                        Thumbnail varchar(200),
                                                        Description text,
                                                        PublishedDate timestamp,
                                                        Duration interval,
                                                        Views bigint,
                                                        Likes bigint,
                                                        Comments int,
                                                        Favorite_count int,
                                                        Definition varchar(10),
                                                        Caption_Status varchar(50)
                                                            )'''
    cursor.execute(create_query)
    mydb.commit()

    vi_list=[]
    db=Client["youtube_data"]
    coll1=db["channel_details"]
    for vi_data in coll1.find({},{"_id":0, "video_information":1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"])
    df2=pd.DataFrame(vi_list) 

    for index,row in df2.iterrows():
        insert_query='''insert into videos(Channel_Name,
                                                Channel_Id,
                                                Video_Id,
                                                Title,
                                                Tags,
                                                Thumbnail,
                                                Description,
                                                PublishedDate,
                                                Duration,
                                                Views,
                                                Likes,
                                                Comments,
                                                Favorite_count,
                                                Definition,
                                                Caption_Status)

                                        values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
        #print(row)
        values=(row['Channel_Name'],
                row['Channel_Id'],
                row['Video_Id'],
                row['Title'],
                row['Tags'],
                row['Thumbnail'],
                row['Description'],
                row['PublishedDate'],
                row['Duration'],
                row['Views'],
                row['Likes'],
                row['Comments'],
                row['Favorite_count'],
                row['Definition'],
                row['Caption_Status']

                )
    
    
               
        
        
        cursor.execute(insert_query,values)
        mydb.commit()

# %%
mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345",
                        #database="youtube_data",
                        port="5432")
cursor=mydb.cursor()

drop_query='''drop table if exists videos'''
cursor.execute(drop_query)
mydb.commit()

create_query='''create table if not exists videos(Channel_Name varchar(100),
                                                    Channel_Id varchar(100),
                                                    Video_Id varchar(30),
                                                    Title varchar(150),
                                                    Tags text,
                                                    Thumbnail varchar(200),
                                                    Description text,
                                                    PublishedDate timestamp,
                                                    Duration interval,
                                                    Views bigint,
                                                    Likes bigint,
                                                    Comments int,
                                                    Favorite_count int,
                                                    Definition varchar(10),
                                                    Caption_Status varchar(50)
                                                        )'''
cursor.execute(create_query)
mydb.commit()

# %%
vi_list=[]
db=Client["youtube_data"]
coll1=db["channel_details"]
for vi_data in coll1.find({},{"_id":0, "video_information":1}):
    for i in range(len(vi_data["video_information"])):
        vi_list.append(vi_data["video_information"])
df2=pd.DataFrame(vi_data["video_information"])
df2
# Out:
#                               Channel_Name                Channel_Id  \
# 0    Science With Sam - அறிவியல் அறிவோம் !  UChGd9JY4yMegY6PxqpBjpRA
# 1    Science With Sam - அறிவியல் அறிவோம் !  UChGd9JY4yMegY6PxqpBjpRA
# 2    Science With Sam - அறிவியல் அறிவோம் !  UChGd9JY4yMegY6PxqpBjpRA
# 3    Science With Sam - அறிவியல் அறிவோம் !  UChGd9JY4yMegY6PxqpBjpRA
# 4    Science With Sam - அறிவியல் அறிவோம் !  UChGd9JY4yMegY6PxqpBjpRA
# ..                                     ...                       ...
# 250  Science With Sam - அறிவியல் அறிவோம் !  UChGd9JY4yMegY6PxqpBjpRA
# 251  Science With Sam - அறிவியல் அறிவோம் !  UChGd9JY4yMegY6PxqpBjpRA
# 252  Science With Sam - அறிவியல் அறிவோம் !  UChGd9JY4yMegY6PxqpBjpRA
# 253  Science With Sam - அறிவியல் அறிவோம் !  UChGd9JY4yMegY6PxqpBjpRA
# 254  Science With Sam - அறிவியல் அறிவோம் !  UChGd9JY4yMegY6PxqpBjpRA
#
#         Video_Id                                              Title  \
# 0    FTLBylwmrlk  Nobel Prize Chemistry 2023 Tamil | வேதியில் தே...
# ...

# %%
mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345",
                        #database="youtube_data",
                        port="5432")
cursor=mydb.cursor()
for index,row in df2.iterrows():
                insert_query='''insert into videos(Channel_Name,
                                                Channel_Id,
                                                Video_Id,
                                                Title,
                                                Tags,
                                                Thumbnail,
                                                Description,
                                                PublishedDate,
                                                Duration,
                                                Views,
                                                Likes,
                                                Comments,
                                                Favorite_count,
                                                Definition,
                                                Caption_Status)

                                        values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
        
#print(row)
values=(row['Channel_Name'],
        row['Channel_Id'],
        row['Video_Id'],
        row['Title'],
        row['Tags'],
        row['Thumbnail'],
        row['Description'],
        row['PublishedDate'],
        row['Duration'],
        row['Views'],
        row['Likes'],
        row['Comments'],
        row['Favorite_count'],
        row['Definition'],
        row['Caption_Status']

                )
    
    
               
        
        
cursor.execute(insert_query,values)
mydb.commit()

# %%
#comments
def comments_table():
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345",
                        #database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()
        
    drop_query='''drop table if exists comments'''
    cursor.execute(drop_query)
    mydb.commit()

    create_query='''create table if not exists comments(Comment_Id varchar(100) primary key,
                                                        Video_Id varchar(50),
                                                        Comment_Text text
                                                        
                                                            )'''
    cursor.execute(create_query)
    mydb.commit()

    com_list=[]
    db=Client["youtube_data"]
    coll1=db["channel_details"]
    for com_data in coll1.find({},{"_id":0, "comment_information":1}):
        for i in range(len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"])
    df3=pd.DataFrame(com_data["comment_information"]) 

    for index,row in df3.iterrows():
        insert_query='''insert into comments(Comment_Id,
                                                Video_Id,
                                                Comment_Text
                                                
                                                )

                                            values(%s,%s,%s)'''
        values=(row['Comment_Id'],
                row['Video_Id'],
                row['Comment_Text']
                
                
                )
        
        
        cursor.execute(insert_query,values)
        mydb.commit()

# %%
comments_table()

# %%
com_list=[]
db=Client["youtube_data"]
coll1=db["channel_details"]
for com_data in coll1.find({},{"_id":0, "comment_information":1}):
    for i in range(len(com_data["comment_information"])):
        com_list.append(com_data["comment_information"])
df3=pd.DataFrame(com_data["comment_information"]) 
df3
# Out:
#                       Comment_Id     Video_Id  \
# 0     Ugz5p6soVO2yW6PvuMF4AaABAg  FTLBylwmrlk
# 1     Ugzo5e01DzUt30rBvVh4AaABAg  FTLBylwmrlk
# 2     UgzI53TrpRIOgdbFXJB4AaABAg  FTLBylwmrlk
# 3     Ugwz64-G-eDoY2S0hal4AaABAg  FTLBylwmrlk
# 4     Ugwvt3EzWEXNN2H01XF4AaABAg  FTLBylwmrlk
# ...                          ...          ...
# 8437  Ugw2TIOLNHws48YSi3t4AaABAg  Nykz9_Vh2Bo
# 8438  Ugz2k8-aQqlKgRYf-aZ4AaABAg  Nykz9_Vh2Bo
# 8439  UgyWirW7SAXB8-8CL3x4AaABAg  Nykz9_Vh2Bo
# 8440  Ugz2ZsLaempEvA0Y5-p4AaABAg  Nykz9_Vh2Bo
# 8441  Ugxx5nN4H1OLSsX05254AaABAg  Nykz9_Vh2Bo
#
#                                            Comment_Text  \
# 0     Sir pls tell particle physics vs Theoretical p...
# 1                       Sir are you busy? No videos yet
# 2                    Sir, can you share your contact id
# 3     Share your channel to someone you trust .so we...
# 4     Why you are not upload your science findings? ...
# ...                                                 ...
# ...

# %%
for index,row in df3.iterrows():
        insert_query='''insert into comments(Comment_Id,
                                                Video_Id,
                                                Comment_Text
                                                 )

                                            values(%s,%s,%s)'''
        values=(row['Comment_Id'],
                row['Video_Id'],
                row['Comment_Text']
                )
        cursor.execute(insert_query,values)
        mydb.commit()

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8442 entries, 0 to 8441
# Columns: 8442 entries, 0 to 8441
# dtypes: object(8442)
# memory usage: 543.7+ MB

# %%
def tables():
    channels_table()
    playlists_table()
    videos_table()
    comments_table()
    
    return "tables created successfully"

# %%
Tables=tables()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 Tables=tables()
#
# Cell In[62], line 4, in tables()
#       2 channels_table()
#       3 playlists_table()
# ----> 4 videos_table()
#       5 comments_table()
#       7 return "tables created successfully"
#
# Cell In[10], line 60, in videos_table()
#      42 insert_query='''insert into videos(Channel_Name,
#      43                                         Channel_Id,
#      44                                         Video_Id,
#    (...)
#      57
#      58                                 values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
#      59 #print(row)
# ---> 60 values=(row['Channel_Name'],
#      61         row['Channel_Id'],
#      62         row['Video_Id'],
#      63         row['Title'],
#      64         row['Tags'],
#      65         row['Thumbnail'],
# ...

# %%
Tables
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 Tables
#
# NameError: name 'Tables' is not defined

# %%
def show_channels_table():
    ch_list=[]
    db=Client["youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0, "channel_information":1}):
        # for i in range(len(ch_data["channel_information"])):
            ch_list.append(ch_data["channel_information"])
    df=st.dataframe(ch_list) 
    return df

# %%
def show_playlist_table():
    pl_list=[]
    db=Client["youtube_data"]
    coll1=db["channel_details"]
    for pl_data in coll1.find({},{"_id":0, "playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append(pl_data["playlist_information"][i])
    df1=st.dataframe(pl_list)
    return df1

# %%
def show_videos_table():
    vi_list=[]
    db=Client["youtube_data"]
    coll1=db["channel_details"]
    for vi_data in coll1.find({},{"_id":0, "video_information":1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"])
    df2=st.dataframe(vi_list) 
    return df2

# %%
def show_comments_table():
    com_list=[]
    db=Client["youtube_data"]
    coll1=db["channel_details"]
    for com_data in coll1.find({},{"_id":0, "comment_information":1}):
        for i in range(len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"])
    df3=st.dataframe(com_list) 
    return df3

# %%
#streamlit part
with st.sidebar:
    st.title(":red[YOUTUBE DATA HAVERSTING AND WAREHOUSING]")
    st.header("skill Take Away")
    st.caption("Python Scripting")
    st.caption("Data Collection")
    st.caption("MongoD8")
    st.caption("API Integration")
    st.caption("Data Management using MongoDB and SQL")

channel_id=st.text_input("Enter the channel ID")

if st.button("collect and store data"):
    ch_ids=[]
    db=Client["youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}): 
        ch_ids.append(ch_data["channel_information"]["Channel_Id"])

    if channel_id in ch_ids:
        st.success("Channel Details of the given channel id already exists")

    else:
        insert=channel_details(channel_id)
        st.success(insert)

if st.button("Migrate to Sql"): 
    Table=tables() 
    st.success(Table)

show_table=st.radio("SELECT THE TABLE FOR VIEW", ("CHANNELS", "PLAYLISTS", "VIDEOS", "COMMENTS"))


if show_table=="CHANNELS": 
    show_channels_table()

elif show_table=="PLAYLISTS": 
    show_playlist_table()

elif show_table=="VIDEOS": 
    show_videos_table()

elif show_table=="COMMENTS": 
    show_comments_table()

# %%
#sql connection
mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345",
                        #database="youtube_data",
                        port="5432")
cursor=mydb.cursor()

question=st.selectbox("Select your question",("1. All the channeID and the channel name",
                                              "2. channels with most number of videos",
                                              "3. 10 most viewed videos",
                                              "4. comments in each videos",
                                              "5. Videos with higest likes",
                                              "6. likes of all videos",
                                              "7. views of each channel",
                                              "8. videos published in the year of 2822",
                                              "9. average duration of all videos in each channel", 
                                              "10. videos with highest number of comments"))

# %%
if question=="1. All the videos and the channel name":
    query1='''select title as videos, channel_name as channelname from videos''' 
    cursor.execute(query1)
    mydb.commit()
    t1=cursor.fetchall()
    df=pd.DataFrame(t1,columns=["video title", "channel name"]) 
    st.write(df)

elif question=="2. channels with most number of videos":
    query2='''select channel_name as channelname, total_videos as no videos from channels 
                order by total_videos desc'''
    cursor.execute(query2)
    mydb.commit()
    t2=cursor.fetchall()
    df2=pd.DataFrame(t2, columns=["channel name", "No of videos"])
    st.write(df2)

elif question=="3. 10 most viewed videos":
    query3='''select views as views, channel_name as channelname, title as videotitle from videos
      where views is not null order by views desc limit 10'''
    cursor.execute(query3)
    mydb.commit()
    t3=cursor.fetchall()
    df3=pd.DataFrame(t3,columns=["views", "channel name", "videotitle"])
    st.write(df3)



elif question=="4. comments in each videos":
    query4='''select comments as no_comments, title as videotitle from videos where comments is not null''' 
    cursor.execute(query4)
    mydb.commit()
    t4=cursor.fetchall()
    df4=pd.DataFrame(t4,columns=["no of comments","videotitle"])
    st.write(df4)

elif question=="5. Videos with higest likes":
    query5='''select title as videotitle, channel_name as channelname, likes as likecount 
             from videos where likes is not null order by likes desc'''
    cursor.execute(query5)
    mydb.commit()
    t5=cursor.fetchall()
    df5=pd.DataFrame(t5,columns=["videotitle", "channelname","likecount"])
    st.write(df5)

elif question=="6. likes of all videos":
    query6='''select likes as likecount, title as videotitle from videos'''
    cursor.execute(query6)
    mydb.commit()
    t6=cursor.fetchall()
    df6=pd.DataFrame(t6,columns=["likecount", "videotitle"])
    st.write(df6)

elif question=="7. views of each channel":
    query7='''select channel_name as channelname ,views as totalviews from channels'''
    cursor.execute(query7)
    mydb.commit()
    t7=cursor.fetchall()
    df7=pd.DataFrame(t7,columns=["channel name", "totalviews"])
    st.write(df7)

elif question=="8. videos published in the year of 2022":
    query8='''select title as video_title,published_date as videorelease, channel_name as channelname from videos
            where extract(year from published_date)=2022'''
    cursor.execute(query8)
    mydb.commit()
    t8=cursor.fetchall()
    df8=pd.DataFrame(t8,columns=["videotitle","published_date", "channelname"])
    st.write(df8)

elif question=="9. average duration of all videos in each channel":
    query9='''select channel_name as channelname, AVG(duration) as averageduration from videos group by channel_name'''
    cursor.execute(query9)
    mydb.commit()
    t9=cursor.fetchall()
    df9=pd.DataFrame(t9, columns=["channelname","averageduration"])

    T9=[]
    for index, row in df9.iterrows():
        channel_title=row["channelname"]
        average_duration=row["averageduration"]
        average_duration_str=str(average_duration)
        df1=pd.DataFrame(19)
        T9.append(dict(channeltitle=channel_title, avgduration=average_duration_str))
    df1=pd.DataFrame(T9)
    st.write(df1)

elif question=="10. videos with highest number of comments":

    query10='''select title as videotitle, channel_name as channelname,comments as comments from videos 
                where not null order by comments desc'''
    cursor.execute(query10)
    mydb.commit()
    t10=cursor.fetchall()
    df10=pd.DataFrame(t10,columns=["video title","channel name","comments"])
    st.write(df10)

# %%
mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345",
                        #database="youtube_data",
                        port="5432")
cursor=mydb.cursor()

query1='''select Channel_Id as channelId, channel_name as channelname from channels''' 
cursor.execute(query1)
mydb.commit()
t1=cursor.fetchall()
df=pd.DataFrame(t1,columns=["channelId", "channel name"])
df
# Out:
#                   channelId                           channel name
# 0  UChGd9JY4yMegY6PxqpBjpRA  Science With Sam - அறிவியல் அறிவோம் !

# %%
mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345",
                        #database="youtube_data",
                        port="5432")
cursor=mydb.cursor()
query2='''select Channel_name as channelname, total_videos as no_videos from Channels 
                order by total_videos desc'''
cursor.execute(query2)
mydb.commit()
t2=cursor.fetchall()
df2=pd.DataFrame(t2, columns=["channel name", "No of videos"])
df2
# Out:
#                             channel name  No of videos
# 0  Science With Sam - அறிவியல் அறிவோம் !           255

# %%
query3='''select Playlist_Id as playlistID, channel_name as channelname, title as videotitle from playlists
      limit 10'''
cursor.execute(query3)
mydb.commit()
t3=cursor.fetchall()
df3=pd.DataFrame(t3,columns=["playlistID", "channel name", "videotitle"])
df3
# Out:
#                            playlistID                           channel name  \
# 0  PLgctjL4oxHAsIkA1Np-1Z3U5ufFeVPBxG  Science With Sam - அறிவியல் அறிவோம் !
# 1  PLgctjL4oxHAuP0ALXEJDuawYaTGyguu2F  Science With Sam - அறிவியல் அறிவோம் !
# 2  PLgctjL4oxHAv13mHacoQCGidm6mWlK7Pm  Science With Sam - அறிவியல் அறிவோம் !
# 3  PLgctjL4oxHAtKInGo2EjXOBq4sqfTfll7  Science With Sam - அறிவியல் அறிவோம் !
# 4  PLgctjL4oxHAuTH4vM5Y3Fp-1yNC4Rq4j7  Science With Sam - அறிவியல் அறிவோம் !
# 5  PLgctjL4oxHAs0VfJNQQW1EwL7KZ9LIowl  Science With Sam - அறிவியல் அறிவோம் !
# 6  PLgctjL4oxHAvnDjqxswXeE0P_CIPb6uYH  Science With Sam - அறிவியல் அறிவோம் !
# 7  PLgctjL4oxHAu-RXkV4tveHlaOxLjCNJHK  Science With Sam - அறிவியல் அறிவோம் !
# 8  PLgctjL4oxHAt4WfbhvFDlrr1SdyHRfscT  Science With Sam - அறிவியல் அறிவோம் !
# 9  PLgctjL4oxHAvRKVXTk2IxLLukcIx37M9i  Science With Sam - அறிவியல் அறிவோம் !
#
#                             videotitle
# 0  Quantum Mechanics Lectures in Tamil
# 1                      Richard Feynman
# ...

# %%
mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345",
                        #database="youtube_data",
                        port="5432")
cursor=mydb.cursor()
query4='''select Channel_Id as channelID from playlists limit 16''' 
cursor.execute(query4)
mydb.commit()
t4=cursor.fetchall()
df4=pd.DataFrame(t4,columns=["channelID"])
df4
# Out:
#                    channelID
# 0   UChGd9JY4yMegY6PxqpBjpRA
# 1   UChGd9JY4yMegY6PxqpBjpRA
# 2   UChGd9JY4yMegY6PxqpBjpRA
# 3   UChGd9JY4yMegY6PxqpBjpRA
# 4   UChGd9JY4yMegY6PxqpBjpRA
# 5   UChGd9JY4yMegY6PxqpBjpRA
# 6   UChGd9JY4yMegY6PxqpBjpRA
# 7   UChGd9JY4yMegY6PxqpBjpRA
# 8   UChGd9JY4yMegY6PxqpBjpRA
# 9   UChGd9JY4yMegY6PxqpBjpRA
# 10  UChGd9JY4yMegY6PxqpBjpRA
# 11  UChGd9JY4yMegY6PxqpBjpRA
# 12  UChGd9JY4yMegY6PxqpBjpRA
# 13  UChGd9JY4yMegY6PxqpBjpRA
# 14  UChGd9JY4yMegY6PxqpBjpRA
# 15  UChGd9JY4yMegY6PxqpBjpRA

# %%
mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345",
                        #database="youtube_data",
                        port="5432")
query5='''select Subscribers as subcribers, channel_name as channelname, Views as Viewscount 
             from channels where likes is not null order by likes desc'''
cursor.execute(query5)
mydb.commit()
t5=cursor.fetchall()
df5=pd.DataFrame(t5,columns=["subcribers","channelname","Viewscount"])
df5
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# Cell In[69], line 8
#       1 mydb=psycopg2.connect(host="localhost",
#       2                         user="postgres",
#       3                         password="12345",
#       4                         #database="youtube_data",
#       5                         port="5432")
#       6 query5='''select Subscribers as subcribers, channel_name as channelname, Views as Viewscount
#       7              from channels where likes is not null order by likes desc'''
# ----> 8 cursor.execute(query5)
#       9 mydb.commit()
#      10 t5=cursor.fetchall()
#
# UndefinedColumn: column "likes" does not exist
# LINE 2:              from channels where likes is not null order by ...
#                                          ^

# %%
mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345",
                        #database="youtube_data",
                        port="5432")
query6='''select likes as likecount, title as videotitle from videos'''
cursor.execute(query6)
mydb.commit()
t6=cursor.fetchall()
df6=pd.DataFrame(t6,columns=["likecount", "videotitle"])
df6
# Out:
# ---------------------------------------------------------------------------
# InFailedSqlTransaction                    Traceback (most recent call last)
# Cell In[70], line 7
#       1 mydb=psycopg2.connect(host="localhost",
#       2                         user="postgres",
#       3                         password="12345",
#       4                         #database="youtube_data",
#       5                         port="5432")
#       6 query6='''select likes as likecount, title as videotitle from videos'''
# ----> 7 cursor.execute(query6)
#       8 mydb.commit()
#       9 t6=cursor.fetchall()
#
# InFailedSqlTransaction: current transaction is aborted, commands ignored until end of transaction block

# %%
query7='''select channel_name as channelname ,views as totalviews from channels'''
cursor.execute(query7)
mydb.commit()
t7=cursor.fetchall()
df7=pd.DataFrame(t7,columns=["channel name", "totalviews",])
df7
# Out:
#                             channel name  totalviews
# 0  Science With Sam - அறிவியல் அறிவோம் !     3821416

# %%
mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345",
                        #database="youtube_data",
                        port="5432")
query8='''select Subscribers as subcribers ,Channel_Description as channel_description, channel_name as channelname 
from channels'''
cursor.execute(query8)
mydb.commit()
t8=cursor.fetchall()
df8=pd.DataFrame(t8,columns=["subcribers", "channel_description","channelname"])
df8
# Out:
#    subcribers                                channel_description  \
# 0       58400  நான், இயற்பியல் துறையில் முனைவர் பட்டம், ஜப்பா...
#
#                              channelname
# 0  Science With Sam - அறிவியல் அறிவோம் !

# %%
mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345",
                        #database="youtube_data",
                        port="5432")
query9='''select channel_name as channelname, AVG(duration) as averageduration from videos group by channel_name'''
cursor.execute(query9)
mydb.commit()
t9=cursor.fetchall()
df9=pd.DataFrame(t9, columns=["channelname","averageduration"])
df9
# Out:
# ---------------------------------------------------------------------------
# InFailedSqlTransaction                    Traceback (most recent call last)
# Cell In[71], line 7
#       1 mydb=psycopg2.connect(host="localhost",
#       2                         user="postgres",
#       3                         password="12345",
#       4                         #database="youtube_data",
#       5                         port="5432")
#       6 query9='''select channel_name as channelname, AVG(duration) as averageduration from videos group by channel_name'''
# ----> 7 cursor.execute(query9)
#       8 mydb.commit()
#       9 t9=cursor.fetchall()
#
# InFailedSqlTransaction: current transaction is aborted, commands ignored until end of transaction block

# %%
mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345",
                        #database="youtube_data",
                        port="5432")
query10='''select Comment_Id as commentID , Comment_Text as Text, Video_Id as videoID from  comments
limit 51'''
cursor.execute(query10)
mydb.commit()
t10=cursor.fetchall()
df10=pd.DataFrame(t10,columns=["CommentID","Text", "videoID"])
df10
# Out:
#                      CommentID  \
# 0   Ugz5p6soVO2yW6PvuMF4AaABAg
# 1   Ugzo5e01DzUt30rBvVh4AaABAg
# 2   UgzI53TrpRIOgdbFXJB4AaABAg
# 3   Ugwz64-G-eDoY2S0hal4AaABAg
# 4   Ugwvt3EzWEXNN2H01XF4AaABAg
# 5   UgzKR8mgIpLzpDcXrI54AaABAg
# 6   UgxNjsKEBIT_jXFnjw94AaABAg
# 7   UgxDTBNwC4rIeaJak4V4AaABAg
# 8   UgzClU5APbd3tvVvygt4AaABAg
# 9   Ugw1hXhWtwAuYFpgd8h4AaABAg
# 10  UgyxejgJSUlUus3XDHR4AaABAg
# 11  UgxDHngIjnH07AustVx4AaABAg
# 12  UgyJ5p0wOt-SumULo2Z4AaABAg
# 13  UgxY-0wvOJr2y3xTOAt4AaABAg
# 14  UgzZ-1HK1ldUBWwkyfZ4AaABAg
# 15  UgxBaVGakhVfwZLiVE54AaABAg
# 16  UgxrXyu97cZAmaMxGhx4AaABAg
# 17  Ugxh-99VF1at50KenX54AaABAg
# 18  UgyAI6m2gDtculiaL2h4AaABAg
# 19  UgyFs9LLP7dW1dB7nGR4AaABAg
# 20  UgyjQcs2E178jYdzf6x4AaABAg
# 21  UgwI7aDaDIGxixjcIeN4AaABAg
# 22  UgzFqYQhQF2ZQVUoyy14AaABAg
# 23  UgyBmzG9RxrbkJ5i1LN4AaABAg
# 24  UgyhUyuOe9Cp7CLkvN14AaABAg
# 25  UgwuOA_UhUvl8fxeX514AaABAg
# 26  UgyQGvcWHbpusav7Zcl4AaABAg
# 27  UgzidqPY0xtX-tdCLOV4AaABAg
# 28  Ugw6lp6mmzODVlue7FB4AaABAg
# ...
